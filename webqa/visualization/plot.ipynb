# %%
import json, random, time, os, base64
import numpy as np
from pprint import pprint
from collections import Counter, defaultdict
import cv2
import matplotlib.pyplot as plt
np.set_printoptions(precision=4)
from PIL import Image
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True
from io import BytesIO
from tqdm import tqdm
import matplotlib.pyplot as plt

# %%
dataset = json.load(open("../../../data/WebQA_train_val.json", "r"))

# %%
print(Counter([dataset[k]['split'] for k in dataset]))
print(len(set([dataset[k]['Guid'] for k in dataset])))
print(Counter([dataset[k]['Qcate'] for k in dataset]))
print(len(set([dataset[k]['topic'] for k in dataset])))
# Out:
# Counter({'train': 36766, 'val': 4966})
# 41732
# Counter({'text': 20267, 'YesNo': 7320, 'Others': 5412, 'choose': 4220, 'number': 2118, 'color': 1830, 'shape': 565})
# 441

# %%
qcate2count = dict(Counter([dataset[k]['Qcate'] for k in dataset]))

# %% [markdown]
# ### Text Categories vs. Count

# %%
import matplotlib.pyplot as plt
# Pie chart
labels = list(qcate2count.keys())
sizes = list(qcate2count.values())
#colors
colors = ['#8ED3C7','#FFFFB4','#BEBADA','#FB8072','#7FB1D4','#FDB462','#FDCDE5']
#explsion
explode = (0.05,0.05,0.05,0.05,0.05,0.05,0.05)
 
plt.pie(sizes, colors=colors, labels=labels, autopct='%1.1f%%', startangle=90, pctdistance=0.85, explode = explode)
#draw circle
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Equal aspect ratio ensures that pie is drawn as a circle
# ax1.axis('equal')  
plt.tight_layout()
plt.title("WebQA: Text Categories vs. Count")
plt.savefig('figs/textCat2count.png', dpi=200, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Question Categories vs. Count

# %%
# Pie chart
labels = list(qcate2count.keys())[:-1]
sizes = list(qcate2count.values())[:-1]
#colors
colors = ['#8ED3C7','#FFFFB4','#BEBADA','#FB8072','#7FB1D4','#FDB462']
#explsion
explode = (0.05,0.05,0.05,0.05,0.05,0.05)
 
plt.pie(sizes, colors=colors, labels=labels, autopct='%1.1f%%', startangle=90, pctdistance=0.85, explode = explode)
#draw circle
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Equal aspect ratio ensures that pie is drawn as a circle
# ax1.axis('equal')  
plt.tight_layout()
plt.title("\nWebQA: Question Categories vs. Count")
plt.savefig('figs/textQCat2count.png', dpi=200,bbox_inches='tight')
plt.show()
